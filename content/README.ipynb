# %% [markdown]
# # Welcome
#
# This is a demo of Python and Parselmouth running in your browser, based on Pyodide, Emscripten, and JupyterLite.

# %% [markdown]
# Check out these [example notebooks from the documentation](https://parselmouth.readthedocs.io/en/latest/examples.html):
#
# - [Plotting](./plotting.ipynb)
# - [Batch processing of files](./batch_processing.ipynb)
# - [Pitch manipulation and Praat commands](./pitch_manipulation.ipynb)
